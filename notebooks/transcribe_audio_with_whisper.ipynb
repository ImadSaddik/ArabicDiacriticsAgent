# %%
import torch
from transformers import pipeline

model_id = "openai/whisper-large-v3-turbo"

pipe = pipeline(
    "automatic-speech-recognition",
    model=model_id,
    torch_dtype=torch.float16,
    device="cuda"
)
# Out:
# model.safetensors:  65%|######4   | 1.05G/1.62G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.71M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# Device set to use cuda

# %%
# pass `return_timestamps=True` for timestamps
result = pipe("../audio/audio.mp3", return_timestamps=True)
# Out:
# /home/imad-saddik/anaconda3/envs/arabicDiacriticsAgent/lib/python3.12/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
print(result["text"])
# Out:
#  كل سؤال تسأله للذكاء الاصطناعي وتنبهر من إجابته هناك بشري أجاب على هذا السؤال في وقت لاحق حتى لو كانت أسئلة سخيفة مثل ما طعم لحم الإنسان كان يطلب مني أن أوضح كيف هو طعم لحم الإنسان هل من الممكن طهي لحم الإنسان؟ هل يمكن قليه؟ لا أدري وكل صورة طلبت من الذكاء الاصطناعي أن يخبرك ما بها هناك بشري قام بتصنيف الأنماط الخاصة بتلك الصور في وقت سابق وكل محتوى آمن يعرض لأطفالك الآن هناك بشري قام بتصنيفه مسبقا فخلف الذكاء الاصطناعيها الجميل بشر قموا بتدريبه هذا أمر يجب أن تعرف لأن صورة نمطية التي يعتقدها الأغلب منا مع الأسف التي تقود إلى الكفر والعياذ بالله أن الذكاء الاصطناعي يتعلم لوحده وأنه حاسوب خارق لوحده وأن البشر خلقت شيء حتى أنهم يروجون لذلك في الإعلام بمصطلح الإله الرقمي والعياذ بالله فهل هذا الذكاء الاصطناعي الذي يطوره البشر ويدربونه قوي كفاية ليقضي علينا في يوم ما أو على أقل تقدير يسرق وظائفنا أو على أقل أقل أقل تخدير يسرق خصوصيتنا الإجابة أيها الجميل نعم ومع ذلك من لا يستخدم الذكاء الاصطناع في حياته سيفشل نورا كواليس الذكاء الاصطناعي تدمير البشرية هل الذكاء الاصطناعي يفكر حقا؟ وعليه ما مدى صحة نظرية أنه سيقضي على البشرية في يوم ما؟ أنا سألت شات جي بيتي ما هي أفضل طريقة لنشر السلام في الأرض؟ فقال بحو البشرية طبع الأمر ليس حقيقيا أنا طلبت من شات جي بيتي أن يخبرني هذه الإجابة عندما أسأل هذا السؤال الذكاء الاصطناعي ليس واعيا ولا يفكر كما يفكر البشر بل يعتمد على معادلات رياضية في تحليل معلومات ضخمة من البيانات لا أكثر فهو لا يملك مشاعر أو نية ولكنه يستطيع بحكى ذلك وفق ما دربناه هنا ركز هنا الذكاء الاصطناعي لا يفكر ولن يفكر لوحده وهذا أمر أنت كمسلم أنت موقن تماما بسحته ولا تحتاج أحد ليقنعك بذلك لأنه ببساطة لا يستطيع الإنسان خلق أي شيء تهلكلا قال الله تعالى يا أيها الناس ضرب مثل فاستمعوا له إن الذين تدعون من دون الله لن يخلقوا ذبابا ولو اجتمعوا له هذه الآية ت